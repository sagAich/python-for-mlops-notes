# %%
def check_input(a):
    if a < 0:
        raise ValueError("Negative value is not allowed")
    return a

# %%
check_input(-5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 check_input(-5)
#
# Cell In[2], line 3, in check_input(a)
#       1 def check_input(a):
#       2     if a < 0:
# ----> 3         raise ValueError("Negative value is not allowed")
#       4     return a
#
# ValueError: Negative value is not allowed

# %%
check_input(10)
# Out:
# 10

# %%
def check_input(a):
    if a < 0:
        raise xyz("Negative value is not allowed")

# %%
try:
    check_input(-5)
except ValueError as e:
    print(f"An error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 try:
# ----> 2     check_input(-5)
#       3 except ValueError as e:
#       4     print(f"An error occurred: {e}")
#
# Cell In[6], line 3, in check_input(a)
#       1 def check_input(a):
#       2     if a < 0:
# ----> 3         raise xyz("Negative value is not allowed")
#
# NameError: name 'xyz' is not defined

# %%
# As you can see, the last cell raises a NameError because 'xyz' is not defined. Now following is the way to define a custom exception:
class xyz(Exception): # here Exception is the super class.
    pass
